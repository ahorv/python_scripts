# %% [markdown]
# ### Assessing suitable days: rainless days

# %%
import matplotlib
import numpy as np
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
#%matplotlib notebook
# %matplotlib inline
import csv
import bisect
import datetime
from scipy import interpolate
from matplotlib.dates import DateFormatter

# User defined functions
from load_precip_irrad_from_csv import *

# %% [markdown]
# #### Import Precipitation

# %%
luz_precip = r'precipitation_luz_2017_2018.csv'

df_precip = process_LUZ_Precip(luz_precip)
df_precip.set_index(df_lu_p.datetime, inplace=True)
s_precip = df_precip['rka150d0']       # daily precipitaion in mm 

#df_precip.head(n=2)

# %% [markdown]
# #### Import sunshine duration, relative to the absolute possible daily sum

# %%
dur_csv = r'sunshine_duration_2017_2018.csv'

df_rel = process_LUZ_dur(dur_csv)
df_rel.set_index(df_rel.datetime, inplace=True)
df_rel['sremaxdv'] = pd.to_numeric(df_rel['sremaxdv'], errors='coerce')
s_rel = df_rel['sremaxdv']          # in percent

# %% [markdown]
# #### Precipitation in 2017 near Luzern at Long: 8°18' Lat: 47°02'

# %%
year = '2017-'   
s_day = '11-17' # beginning of observation
e_day = '12-31' # end of observation
start = year + s_day
end   = year + e_day

s_precip_17 = s_precip.loc[start:end]

fig, ax = plt.subplots(figsize=(20,5))
ax.bar(s_precip_17.index, s_precip_17.values, label='relat. possible sunshine duration', color= 'blue')

ax.set_xlabel('[Year - Month/Day]', fontsize=12)
ax.set_ylabel('relative sunshine durration [%]', fontsize=12)
ax.set_title('Sunshine duration in {} from {} to {}'.format(year.strip('-'),s_day,e_day))
ax.legend(loc='upper left')
ax.grid(b=None, which='major', axis='both')

ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#ax.xaxis.set_major_locator(mdates.DayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
fig.autofmt_xdate()

# %% [markdown]
# #### Zoom in on 2017: 9.30 - 10.31

# %%
year = '2017-'   
s_day = '09-30' # beginning of observation
e_day = '10-31' # end of observation
start = year + s_day
end   = year + e_day

s_precip_1 = s_precip.loc[start:end]

fig, ax = plt.subplots(figsize=(20,5))
ax.bar(s_precip_1.index, s_precip_1.values, label='relat. possible sunshine duration', color= 'blue')

ax.set_xlabel('[Year - Month/Day]', fontsize=12)
ax.set_ylabel('relative sunshine durration [%]', fontsize=12)
ax.set_title('Sunshine duration in {} from {} to {}'.format(year.strip('-'),s_day,e_day))
ax.legend(loc='upper left')
ax.grid(b=None, which='major', axis='both')

ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#ax.xaxis.set_major_locator(mdates.DayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
fig.autofmt_xdate()

# %% [markdown]
# #### Precipitation in 2018 near Luzern at Long: 8°18' Lat: 47°02'

# %%
year = '2018-'   
s_day = '01-01' # beginning of observation
e_day = '11-03' # end of observation
start = year + s_day
end   = year + e_day

s_rel_18 = s_rel.loc[start:end]
fig, ax = plt.subplots(figsize=(20,5))
ax.bar(s_rel_18.index, s_rel_18.values, label='relat. possible sunshine duration', color= 'orange')

ax.set_xlabel('[Year - Month/Day]', fontsize=12)
ax.set_ylabel('relative sunshine durration [%]', fontsize=12)
ax.set_title('Sunshine duration in {} from {} to {}'.format(year.strip('-'),s_day,e_day))
ax.legend(loc='upper left')
ax.grid(b=None, which='major', axis='both')

ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#ax.xaxis.set_major_locator(mdates.DayLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
fig.autofmt_xdate()

# %% [markdown]
# #### Zoom in on 2018: 09.30 - 11.03

# %%
year = '2018-'   
s_day = '09-30' # beginning of observation
e_day = '11-03' # end of observation
start = year + s_day
end   = year + e_day

df = df_precip.loc[start:end]

fig = plt.figure(1, figsize=(20,4))
df.plot(kind='bar',label='Precipitation',color= 'b')

plt.xlabel('[Year - Month/Day]', fontsize=12)
plt.ylabel('Precipitation [mm]', fontsize=12)
plt.legend(loc='upper left')
plt.grid(b=None, which='major', axis='both')
plt.title('Precipitation in {} from {} to {}'.format(year.strip('-'),s_day,e_day))

fig.autofmt_xdate()
frmt = df.index.to_series().dt.strftime("%Y-%m-%d")
plt.gca().xaxis.set_major_formatter(plt.FixedFormatter(frmt))

# %% [markdown]
# ### Longest dry periodes in 2018
# 21.06.2018 - 03.07.2018 -> 11 days<br>
# 28.07.2018 - 08.08.2018 -> 11 days<br>
# 10.01.2018 - 27.10.2018 -> 25 days<br>
